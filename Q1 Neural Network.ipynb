# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout
from tensorflow.keras import optimizers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tf.random.set_seed(13)
tf.debugging.set_log_device_placement(False)

# %%
df = pd.read_excel('fertility_Diagnosis.xlsx')
df
# Out:
#     Season in which the analysis was performed  Age at the time of analysis  \
# 0                                        -0.33                         0.69
# 1                                        -0.33                         0.94
# 2                                        -0.33                         0.50
# 3                                        -0.33                         0.75
# 4                                        -0.33                         0.67
# ..                                         ...                          ...
# 95                                       -1.00                         0.67
# 96                                       -1.00                         0.61
# 97                                       -1.00                         0.67
# 98                                       -1.00                         0.64
# 99                                       -1.00                         0.69
#
# ...

# %%
X = df.drop(['Diagnosis'], axis = 1)
y = df['Diagnosis']
X
# Out:
#     Season in which the analysis was performed  Age at the time of analysis  \
# 0                                        -0.33                         0.69
# 1                                        -0.33                         0.94
# 2                                        -0.33                         0.50
# 3                                        -0.33                         0.75
# 4                                        -0.33                         0.67
# ..                                         ...                          ...
# 95                                       -1.00                         0.67
# 96                                       -1.00                         0.61
# 97                                       -1.00                         0.67
# 98                                       -1.00                         0.64
# 99                                       -1.00                         0.69
#
# ...

# %%
X_train, X_test = train_test_split(X, test_size=0.3)
print(X_train.shape)
print(X_test.shape)
# Out:
# (70, 9)
# (30, 9)

# %%
y_train, y_test = train_test_split(y, test_size=0.3)
print(y_train.shape)
print(y_test.shape)
# Out:
# (70,)
# (30,)

# %%
print(type(X_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
train_stats = X_train.describe()
train_stats = train_stats.transpose()
train_stats
# Out:
#                                             count      mean       std   min  \
# Season in which the analysis was performed   70.0 -0.084571  0.787275 -1.00
# Age at the time of analysis                  70.0  0.661714  0.112944  0.50
# Childish diseases                            70.0  0.857143  0.352454  0.00
# Accident or serious trauma                   70.0  0.428571  0.498445  0.00
# Surgical intervention                        70.0  0.485714  0.503405  0.00
# High fevers in the last yea                  70.0  0.157143  0.555231 -1.00
# Frequency of alcohol consumption             70.0  0.817143  0.176086  0.20
# Smoking habit                                70.0 -0.328571  0.829203 -1.00
# Number of hours spent sitting per day        70.0  0.379571  0.177824  0.06
#
#                                              25%   50%   75%   max
# Season in which the analysis was performed -1.00 -0.33  1.00  1.00
# Age at the time of analysis                 0.56  0.67  0.75  0.94
# ...

# %%
def norm(x):
    return (x - train_stats['mean'])/train_stats['std']

# %%
norm_x_train = norm(X_train)
norm_x_test = norm(X_test)
norm_x_train.head(10)
# Out:
#     Season in which the analysis was performed  Age at the time of analysis  \
# 14                                    1.377627                     2.463918
# 23                                    1.377627                     0.250439
# 21                                    1.377627                     0.781674
# 18                                    1.377627                     0.781674
# 83                                   -0.311744                     1.755605
# 0                                    -0.311744                     0.250439
# 74                                   -1.162781                    -1.166187
# 9                                     1.377627                    -0.457874
# 24                                    1.377627                    -0.900569
# 28                                    1.377627                    -0.723491
#
#     Childish diseases  Accident or serious trauma  Surgical intervention  \
# ...

# %%
from keras import regularizers
def nn():
    model = Sequential()
    model.add(Dense(3, input_shape = (norm_x_train.shape[1],)))
    model.add(Dense(3,Activation('sigmoid'), kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dense(1))
    
    learning_rate = 0.01
    optimizer = optimizers.SGD(learning_rate)
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                optimizer=optimizer,
                metrics=['accuracy']) 
    return model

EPOCHS = 50
batch_size = 16 # 6 iteration

model = nn()
print('Here is a summary of this model: ')
model.summary()

with tf.device('/CPU:0'): # it can be with '/CPU:0'
# with tf.device('/GPU:0'): # comment the previous line and uncomment this line to train with a GPU, if available.
    history = model.fit(
        norm_x_train, 
        y_train,
        batch_size = batch_size,
        epochs=EPOCHS, 
        verbose=1,
        shuffle=True,
        steps_per_epoch = int(norm_x_train.shape[0] / batch_size) ,
        validation_data = (norm_x_test, y_test),   
    )
# Out:
# Here is a summary of this model:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 3)                 30
#
#  dense_15 (Dense)            (None, 3)                 12
#
#  dense_16 (Dense)            (None, 1)                 4
#
# ...
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/3866944753.py in <module>
#      22 with tf.device('/CPU:0'): # it can be with '/CPU:0'
#      23 # with tf.device('/GPU:0'): # comment the previous line and uncomment this line to train with a GPU, if available.
# ---> 24     history = model.fit(
#      25         norm_x_train,
# ...

# %%
print('Summary of the results after each epoch: ')
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Summary of the results after each epoch:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/1896178679.py in <module>
#       1 print('Summary of the results after each epoch: ')
# ----> 2 hist = pd.DataFrame(history.history)
#       3 hist['epoch'] = history.epoch
#       4 hist.tail()
#
# NameError: name 'history' is not defined

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Cross-Validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/2682560186.py in <module>
#       1 from matplotlib import pyplot as plt
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Cross-Validation'], loc='upper left')
plt.show()

# %%
print('Train Split: ')
loss, accuracy = model.evaluate(norm_x_train, y_train, verbose=1)

print("Accuracy   : {:5.2f} ".format(accuracy))
# Out:
# Train Split:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/4073165709.py in <module>
#       1 print('Train Split: ')
# ----> 2 loss, accuracy = model.evaluate(norm_x_train, y_train, verbose=1)
#       3
#       4 print("Accuracy   : {:5.2f} ".format(accuracy))
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ...

# %%
print('Evaluation Split: ')
loss, accuracy =  model.evaluate(norm_x_test, y_test, verbose=2)

print("Accuracy   : {:5.2f} ".format(accuracy))
# Out:
# Evaluation Split:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9620/2024950135.py in <module>
#       1 print('Evaluation Split: ')
# ----> 2 loss, accuracy =  model.evaluate(norm_x_test, y_test, verbose=2)
#       3
#       4 print("Accuracy   : {:5.2f} ".format(accuracy))
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ...
